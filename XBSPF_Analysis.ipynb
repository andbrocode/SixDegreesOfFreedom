# %% [markdown]
# # Analyse BlueSeis BSPF Events

# %%
import os
# import obspy as obs
# import numpy as np
import matplotlib.pyplot as plt

from sixdegrees import sixdegrees

# %% [markdown]
# ## Configurations

# %% [markdown]
# Set configuration parameters for the event and data

# %%
config = {
    # Required time window parameters
    'tbeg': "2025-03-20 08:39:10",  # Start time
    'tend': "2025-03-20 08:39:40",  # End time
    
    # event
    'origin_time': "2025-03-20 03:39:05",
    'magnitude': 3.9,
    
    # Station coordinates (required)
    'station_lon': -116.455439,  # BSPF longitude
    'station_lat': 33.610643,    # BSPF latitude
    
    # SEED identifiers
    'seed': "XX.BSPF..",     # Default seed ID
    'rot_seed': ["PY.BSPF..HJZ", "PY.BSPF..HJN", "PY.BSPF..HJE"],  # Rotation sensor seed ID
    'tra_seed': ["PY.PFOIX..HHZ", "PY.PFOIX..HHN", "PY.PFOIX..HHE"],  # Translation sensor seed ID
    
    # data source
    'data_source': "fdsn",
    'fdsn_client_rot': "IRIS",
    'fdsn_client_tra': "IRIS",

    # 'data_source': "sds",
    # 'path_to_sds_rot': "./data/",    # SDS path for rotation data
    # 'path_to_sds_tra': "./data/",  # SDS path for translation data
    # 'path_to_inv_rot': "./inventory/rotation.xml",  # Rotation station inventory
    # 'path_to_inv_tra': "./inventory/translation.xml",  # Translation station inventory
    
    # 'data_source': "mseed_file",
    # 'path_to_mseed_file': "./data/eventM62_6c.mseed",

    # Path configurations
    'workdir': "./",            # Working directory
    'path_to_data_out': "./data/",  # Output directory

    # Project information
    'project': "BSPF_Analysis",  # Project name
    
    # Rotation and translation data
    'rotate_zne': True,

    # Backazimuth calculation parameters
    # 'sampling_rate': 20,        # Sampling rate in Hz
    # 'baz_step': 1,              # Step size for backazimuth search in degrees
    # 'baz_win_sec': 30,          # Window length in seconds
    # 'baz_win_sec_overlap': 15,  # Window overlap in seconds
    
    # Optional parameters
    'verbose': True,            # Print detailed information
}

# %%
config = {
    # Required time window parameters
    'tbeg': "2022-11-22 16:40:00",  # Start time
    'tend': "2022-11-22 16:42:30",  # End time

    # event
    'origin_time': "2022-11-22 16:40:00",
    'magnitude': 6.2,

    
    # Station coordinates (required)
    'station_lon': -116.455439,  # BSPF longitude
    'station_lat': 33.610643,    # BSPF latitude
    
    # SEED identifiers
    'seed': "XX.BSPF..",     # Default seed ID
    'rot_seed': ["PY.BSPF..HJZ", "PY.BSPF..HJN", "PY.BSPF..HJE"],  # Rotation sensor seed ID
    'tra_seed': ["PY.PFOIX..BHZ", "PY.PFOIX..BHN", "PY.PFOIX..BHE"],  # Translation sensor seed ID
    
    # data source
    # 'data_source': "fdsn",
    # 'fdsn_client_rot': "IRIS",
    # 'fdsn_client_tra': "IRIS",

    # 'data_source': "sds",
    # 'path_to_sds_rot': "./data/",    # SDS path for rotation data
    # 'path_to_sds_tra': "./data/",  # SDS path for translation data
    # 'path_to_inv_rot': "./inventory/rotation.xml",  # Rotation station inventory
    # 'path_to_inv_tra': "./inventory/translation.xml",  # Translation station inventory
    
    # 'data_source': "mseed_file",
    'path_to_mseed_file': "./data/eventM62_6c.mseed",

    # Path configurations
    'workdir': "./",            # Working directory
    'path_to_data_out': "./output/",  # Output directory

    # Project information
    'project': "BSPF_Analysis",  # Project name
    
    # Backazimuth calculation parameters
    # 'sampling_rate': 20,        # Sampling rate in Hz
    # 'baz_step': 1,              # Step size for backazimuth search in degrees
    # 'baz_win_sec': 30,          # Window length in seconds
    # 'baz_win_sec_overlap': 15,  # Window overlap in seconds
    
    # Optional parameters
    'verbose': True,            # Print detailed information
}

# %%
config = {
    # Required time window parameters
    'tbeg': "2025-04-14 09:50:00",  # Start time
    'tend': "2025-04-14 10:00:00",  # End time
    
    # event
    'origin_time': "2022-12-31 12:12:20",
    'magnitude': 4.1,
    
    # Station coordinates (required)
    'station_lon': -116.455439,  # BSPF longitude
    'station_lat': 33.610643,    # BSPF latitude
    
    # SEED identifiers
    'seed': "XX.BSPF..",     # Default seed ID
    'rot_seed': ["PY.BSPF..HJZ", "PY.BSPF..HJN", "PY.BSPF..HJE"],  # Rotation sensor seed ID
    'tra_seed': ["PY.PFOIX..HHZ", "PY.PFOIX..HHN", "PY.PFOIX..HHE"],  # Translation sensor seed ID
    
    # data source
    'data_source': "fdsn",
    'fdsn_client_rot': "IRIS",
    'fdsn_client_tra': "IRIS",

    # 'data_source': "sds",
    # 'path_to_sds_rot': "./data/",    # SDS path for rotation data
    # 'path_to_sds_tra': "./data/",  # SDS path for translation data
    # 'path_to_inv_rot': "./inventory/rotation.xml",  # Rotation station inventory
    # 'path_to_inv_tra': "./inventory/translation.xml",  # Translation station inventory
    
    # 'data_source': "mseed_file",
    # 'path_to_mseed_file': "./data/eventM41_6c.mseed",

    # Path configurations
    'workdir': "./",            # Working directory
    'path_to_data_out': "./output/",  # Output directory

    # Project information
    'project': "BSPF_Analysis",  # Project name
    
    # Backazimuth calculation parameters
    # 'sampling_rate': 20,        # Sampling rate in Hz
    # 'baz_step': 1,              # Step size for backazimuth search in degrees
    # 'baz_win_sec': 30,          # Window length in seconds
    # 'baz_win_sec_overlap': 15,  # Window overlap in seconds
    
    # Optional parameters
    'verbose': True,            # Print detailed information
}

# %%
from obspy.clients.fdsn.client import Client
from obspy import UTCDateTime

starttime = UTCDateTime("2025-04-14 09:50:00")
endtime = UTCDateTime("2025-04-14 10:00:00")

cl = Client("IRIS")

sta = cl.get_stations(network="PY", starttime=starttime, endtime=endtime, level="response")
print(sta)
# Out:
# Inventory created at 2025-04-14T10:25:26.145600Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.52
# 		    http://service.iris.edu/fdsnws/station/1/query?starttime=2025-04-...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (1):
# 			PY
# 		Stations (16):
# 			PY.BPH01 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH02 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH03 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH04 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH05 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH06 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH07 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH08 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH09 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH10 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH11 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH12 (Pinon Flat Observatory, CA, USA)
# 			PY.BPH13 (Pinon Flat Observatory, CA, USA)
# 			PY.BSPF (iXblue Blueseis, Pinon Flat Obs., Anza, CA, USA)
# 			PY.PFOIX (Pinyon Flats Observatory, IXBlue, CA, USA)
# 			PY.TPFO (Pinon Flats, CA, USA)
# 		Channels (540):
# 			PY.BPH01..ACE, PY.BPH01..BDO, PY.BPH01..BHZ, PY.BPH01..BHN,
# 			PY.BPH01..BHE, PY.BPH01..HHZ, PY.BPH01..HHN, PY.BPH01..HHE,
# 			PY.BPH01..LCE, PY.BPH01..LCQ, PY.BPH01..LDO, PY.BPH01..LHZ,
# 			PY.BPH01..LHN, PY.BPH01..LHE, PY.BPH01..LOG, PY.BPH01..OCF,
# 			PY.BPH01..UHZ, PY.BPH01..UHN, PY.BPH01..UHE, PY.BPH01..VCO,
# 			PY.BPH01..VEA, PY.BPH01..VEC, PY.BPH01..VEP, PY.BPH01..VHZ,
# 			PY.BPH01..VHN, PY.BPH01..VHE, PY.BPH01..VKI, PY.BPH01..VM0,
# 			PY.BPH01..VM1, PY.BPH01..VM2, PY.BPH01..VM3, PY.BPH01..VM4,
# 			PY.BPH01..VM5, PY.BPH01..VM6, PY.BPH01..VPB, PY.BPH02..ACE,
# 			PY.BPH02..BHZ, PY.BPH02..BHN, PY.BPH02..BHE, PY.BPH02..HHZ,
# 			PY.BPH02..HHN, PY.BPH02..HHE, PY.BPH02..HNZ, PY.BPH02..HNN,
# 			PY.BPH02..HNE, PY.BPH02..LCE, PY.BPH02..LCQ, PY.BPH02..LHZ,
# 			PY.BPH02..LHN, PY.BPH02..LHE, PY.BPH02..LOG, PY.BPH02..OCF,
# 			PY.BPH02..UHZ, PY.BPH02..UHN, PY.BPH02..UHE, PY.BPH02..VCO,
# 			PY.BPH02..VEA, PY.BPH02..VEC, PY.BPH02..VEP, PY.BPH02..VHZ,
# 			PY.BPH02..VHN, PY.BPH02..VHE, PY.BPH02..VKI, PY.BPH02..VM0,
# 			PY.BPH02..VM1, PY.BPH02..VM2, PY.BPH02..VM3, PY.BPH02..VM4,
# 			PY.BPH02..VM5, PY.BPH02..VM6, PY.BPH02..VPB, PY.BPH03..ACE,
# 			PY.BPH03..BDO, PY.BPH03..BHZ, PY.BPH03..BHN, PY.BPH03..BHE,
# 			PY.BPH03..HHZ, PY.BPH03..HHN, PY.BPH03..HHE, PY.BPH03..LCE,
# 			PY.BPH03..LCQ, PY.BPH03..LDO, PY.BPH03..LHZ, PY.BPH03..LHN,
# 			PY.BPH03..LHE, PY.BPH03..LOG, PY.BPH03..OCF, PY.BPH03..UHZ,
# 			PY.BPH03..UHN, PY.BPH03..UHE, PY.BPH03..VCO, PY.BPH03..VEA,
# 			PY.BPH03..VEC, PY.BPH03..VEP, PY.BPH03..VHZ, PY.BPH03..VHN,
# 			PY.BPH03..VHE, PY.BPH03..VKI, PY.BPH03..VM0, PY.BPH03..VM1,
# 			PY.BPH03..VM2, PY.BPH03..VM3, PY.BPH03..VM4, PY.BPH03..VM5,
# 			PY.BPH03..VM6, PY.BPH03..VPB, PY.BPH04..ACE, PY.BPH04..BHZ,
# 			PY.BPH04..BHN, PY.BPH04..BHE, PY.BPH04..HHZ, PY.BPH04..HHN,
# 			PY.BPH04..HHE, PY.BPH04..HNZ, PY.BPH04..HNN, PY.BPH04..HNE,
# 			PY.BPH04..LCE, PY.BPH04..LCQ, PY.BPH04..LHZ, PY.BPH04..LHN,
# 			PY.BPH04..LHE, PY.BPH04..LOG, PY.BPH04..OCF, PY.BPH04..UHZ,
# 			PY.BPH04..UHN, PY.BPH04..UHE, PY.BPH04..VCO, PY.BPH04..VEA,
# 			PY.BPH04..VEC, PY.BPH04..VEP, PY.BPH04..VHZ, PY.BPH04..VHN,
# 			PY.BPH04..VHE, PY.BPH04..VKI, PY.BPH04..VM0, PY.BPH04..VM1,
# 			PY.BPH04..VM2, PY.BPH04..VM3, PY.BPH04..VM4, PY.BPH04..VM5,
# 			PY.BPH04..VM6, PY.BPH04..VPB, PY.BPH05..ACE, PY.BPH05..BDO,
# 			PY.BPH05..BHZ, PY.BPH05..BHN, PY.BPH05..BHE, PY.BPH05..HHZ,
# 			PY.BPH05..HHN, PY.BPH05..HHE, PY.BPH05..LCE, PY.BPH05..LCQ,
# 			PY.BPH05..LDO, PY.BPH05..LHZ, PY.BPH05..LHN, PY.BPH05..LHE,
# 			PY.BPH05..LOG, PY.BPH05..OCF, PY.BPH05..UHZ, PY.BPH05..UHN,
# 			PY.BPH05..UHE, PY.BPH05..VCO, PY.BPH05..VEA, PY.BPH05..VEC,
# 			PY.BPH05..VEP, PY.BPH05..VHZ, PY.BPH05..VHN, PY.BPH05..VHE,
# 			PY.BPH05..VKI, PY.BPH05..VM0, PY.BPH05..VM1, PY.BPH05..VM2,
# 			PY.BPH05..VM3, PY.BPH05..VM4, PY.BPH05..VM5, PY.BPH05..VM6,
# 			PY.BPH05..VPB, PY.BPH06..ACE, PY.BPH06..BDO, PY.BPH06..BHZ,
# 			PY.BPH06..BHN, PY.BPH06..BHE, PY.BPH06..HHZ, PY.BPH06..HHN,
# 			PY.BPH06..HHE, PY.BPH06..LCE, PY.BPH06..LCQ, PY.BPH06..LDO,
# 			PY.BPH06..LHZ, PY.BPH06..LHN, PY.BPH06..LHE, PY.BPH06..LOG,
# 			PY.BPH06..OCF, PY.BPH06..UHZ, PY.BPH06..UHN, PY.BPH06..UHE,
# 			PY.BPH06..VCO, PY.BPH06..VEA, PY.BPH06..VEC, PY.BPH06..VEP,
# 			PY.BPH06..VHZ, PY.BPH06..VHN, PY.BPH06..VHE, PY.BPH06..VKI,
# 			PY.BPH06..VM0, PY.BPH06..VM1, PY.BPH06..VM2, PY.BPH06..VM3,
# 			PY.BPH06..VM4, PY.BPH06..VM5, PY.BPH06..VM6, PY.BPH06..VPB,
# 			PY.BPH07..ACE, PY.BPH07..BDO, PY.BPH07..BHZ, PY.BPH07..BHN,
# 			PY.BPH07..BHE, PY.BPH07..HHZ, PY.BPH07..HHN, PY.BPH07..HHE,
# 			PY.BPH07..LCE, PY.BPH07..LCQ, PY.BPH07..LDO, PY.BPH07..LHZ,
# 			PY.BPH07..LHN, PY.BPH07..LHE, PY.BPH07..LOG, PY.BPH07..OCF,
# 			PY.BPH07..UHZ, PY.BPH07..UHN, PY.BPH07..UHE, PY.BPH07..VCO,
# 			PY.BPH07..VEA, PY.BPH07..VEC, PY.BPH07..VEP, PY.BPH07..VHZ,
# 			PY.BPH07..VHN, PY.BPH07..VHE, PY.BPH07..VKI, PY.BPH07..VM0,
# 			PY.BPH07..VM1, PY.BPH07..VM2, PY.BPH07..VM3, PY.BPH07..VM4,
# 			PY.BPH07..VM5, PY.BPH07..VM6, PY.BPH07..VPB, PY.BPH08..ACE,
# 			PY.BPH08..BHZ, PY.BPH08..BHN, PY.BPH08..BHE, PY.BPH08..HHZ,
# 			PY.BPH08..HHN, PY.BPH08..HHE, PY.BPH08..HNZ, PY.BPH08..HNN,
# 			PY.BPH08..HNE, PY.BPH08..LCE, PY.BPH08..LCQ, PY.BPH08..LHZ,
# 			PY.BPH08..LHN, PY.BPH08..LHE, PY.BPH08..LOG, PY.BPH08..OCF,
# 			PY.BPH08..UHZ, PY.BPH08..UHN, PY.BPH08..UHE, PY.BPH08..VCO,
# 			PY.BPH08..VEA, PY.BPH08..VEC, PY.BPH08..VEP, PY.BPH08..VHZ,
# 			PY.BPH08..VHN, PY.BPH08..VHE, PY.BPH08..VKI, PY.BPH08..VM0,
# 			PY.BPH08..VM1, PY.BPH08..VM2, PY.BPH08..VM3, PY.BPH08..VM4,
# 			PY.BPH08..VM5, PY.BPH08..VM6, PY.BPH08..VPB, PY.BPH09..ACE,
# 			PY.BPH09..BDO, PY.BPH09..BHZ, PY.BPH09..BHN, PY.BPH09..BHE,
# 			PY.BPH09..HHZ, PY.BPH09..HHN, PY.BPH09..HHE, PY.BPH09..LCE,
# 			PY.BPH09..LCQ, PY.BPH09..LDO, PY.BPH09..LHZ, PY.BPH09..LHN,
# 			PY.BPH09..LHE, PY.BPH09..LOG, PY.BPH09..OCF, PY.BPH09..UHZ,
# 			PY.BPH09..UHN, PY.BPH09..UHE, PY.BPH09..VCO, PY.BPH09..VEA,
# 			PY.BPH09..VEC, PY.BPH09..VEP, PY.BPH09..VHZ, PY.BPH09..VHN,
# 			PY.BPH09..VHE, PY.BPH09..VKI, PY.BPH09..VM0, PY.BPH09..VM1,
# 			PY.BPH09..VM2, PY.BPH09..VM3, PY.BPH09..VM4, PY.BPH09..VM5,
# 			PY.BPH09..VM6, PY.BPH09..VPB, PY.BPH10..ACE, PY.BPH10..BDO,
# 			PY.BPH10..BHZ, PY.BPH10..BHN, PY.BPH10..BHE, PY.BPH10..HHZ,
# 			PY.BPH10..HHN, PY.BPH10..HHE, PY.BPH10..LCE, PY.BPH10..LCQ,
# 			PY.BPH10..LDO, PY.BPH10..LHZ, PY.BPH10..LHN, PY.BPH10..LHE,
# 			PY.BPH10..LOG, PY.BPH10..OCF, PY.BPH10..UHZ, PY.BPH10..UHN,
# 			PY.BPH10..UHE, PY.BPH10..VCO, PY.BPH10..VEA, PY.BPH10..VEC,
# 			PY.BPH10..VEP, PY.BPH10..VHZ, PY.BPH10..VHN, PY.BPH10..VHE,
# 			PY.BPH10..VKI, PY.BPH10..VM0, PY.BPH10..VM1, PY.BPH10..VM2,
# 			PY.BPH10..VM3, PY.BPH10..VM4, PY.BPH10..VM5, PY.BPH10..VM6,
# 			PY.BPH10..VPB, PY.BPH11..ACE, PY.BPH11..BDO, PY.BPH11..BFN,
# 			PY.BPH11..BFE, PY.BPH11..BHZ, PY.BPH11..BHN, PY.BPH11..BHE,
# 			PY.BPH11..HFN, PY.BPH11..HFE, PY.BPH11..HHZ, PY.BPH11..HHN,
# 			PY.BPH11..HHE, PY.BPH11..LCE, PY.BPH11..LCQ, PY.BPH11..LDO,
# 			PY.BPH11..LFN, PY.BPH11..LFE, PY.BPH11..LHZ, PY.BPH11..LHN,
# 			PY.BPH11..LHE, PY.BPH11..LOG, PY.BPH11..OCF, PY.BPH11..UHZ,
# 			PY.BPH11..UHN, PY.BPH11..UHE, PY.BPH11..VCO, PY.BPH11..VEA,
# 			PY.BPH11..VEC, PY.BPH11..VEP, PY.BPH11..VHZ, PY.BPH11..VHN,
# 			PY.BPH11..VHE, PY.BPH11..VKI, PY.BPH11..VM0, PY.BPH11..VM1,
# 			PY.BPH11..VM2, PY.BPH11..VM3, PY.BPH11..VM4, PY.BPH11..VM5,
# 			PY.BPH11..VM6, PY.BPH11..VPB, PY.BPH12..ACE, PY.BPH12..BDO,
# 			PY.BPH12..BHZ, PY.BPH12..BHN, PY.BPH12..BHE, PY.BPH12..HHZ,
# 			PY.BPH12..HHN, PY.BPH12..HHE, PY.BPH12..LCE, PY.BPH12..LCQ,
# 			PY.BPH12..LDO, PY.BPH12..LHZ, PY.BPH12..LHN, PY.BPH12..LHE,
# 			PY.BPH12..LOG, PY.BPH12..OCF, PY.BPH12..UHZ, PY.BPH12..UHN,
# 			PY.BPH12..UHE, PY.BPH12..VCO, PY.BPH12..VEA, PY.BPH12..VEC,
# 			PY.BPH12..VEP, PY.BPH12..VHZ, PY.BPH12..VHN, PY.BPH12..VHE,
# 			PY.BPH12..VKI, PY.BPH12..VM0, PY.BPH12..VM1, PY.BPH12..VM2,
# 			PY.BPH12..VM3, PY.BPH12..VM4, PY.BPH12..VM5, PY.BPH12..VM6,
# 			PY.BPH12..VPB, PY.BPH13..ACE, PY.BPH13..BHZ, PY.BPH13..BHN,
# 			PY.BPH13..BHE, PY.BPH13..HHZ, PY.BPH13..HHN, PY.BPH13..HHE,
# 			PY.BPH13..HNZ, PY.BPH13..HNN, PY.BPH13..HNE, PY.BPH13..LCE,
# 			PY.BPH13..LCQ, PY.BPH13..LHZ, PY.BPH13..LHN, PY.BPH13..LHE,
# 			PY.BPH13..LOG, PY.BPH13..OCF, PY.BPH13..UHZ, PY.BPH13..UHN,
# 			PY.BPH13..UHE, PY.BPH13..VCO, PY.BPH13..VEA, PY.BPH13..VEC,
# 			PY.BPH13..VEP, PY.BPH13..VHZ, PY.BPH13..VHN, PY.BPH13..VHE,
# 			PY.BPH13..VKI, PY.BPH13..VM0, PY.BPH13..VM1, PY.BPH13..VM2,
# 			PY.BPH13..VM3, PY.BPH13..VM4, PY.BPH13..VM5, PY.BPH13..VM6,
# 			PY.BPH13..VPB, PY.BSPF..HJ1, PY.BSPF..HJ2, PY.BSPF..HJ3,
# 			PY.PFOIX..ACE, PY.PFOIX..BHZ, PY.PFOIX..BHN, PY.PFOIX..BHE,
# 			PY.PFOIX..HHZ, PY.PFOIX..HHN, PY.PFOIX..HHE, PY.PFOIX..LCE,
# 			PY.PFOIX..LCQ, PY.PFOIX..LHZ, PY.PFOIX..LHN, PY.PFOIX..LHE,
# 			PY.PFOIX..LOG, PY.PFOIX..OCF, PY.PFOIX..VCO, PY.PFOIX..VEA,
# 			PY.PFOIX..VEC, PY.PFOIX..VEP, PY.PFOIX..VKI, PY.PFOIX..VM0,
# 			PY.PFOIX..VM1, PY.PFOIX..VM2, PY.PFOIX..VM3, PY.PFOIX..VM4,
# 			PY.PFOIX..VM5, PY.PFOIX..VM6, PY.PFOIX..VPB, PY.TPFO..ACE,
# 			PY.TPFO..BHZ, PY.TPFO..BHN, PY.TPFO..BHE, PY.TPFO..HHZ,
# 			PY.TPFO..HHN, PY.TPFO..HHE, PY.TPFO..LCE, PY.TPFO..LCQ,
# 			PY.TPFO..LHZ, PY.TPFO..LHN, PY.TPFO..LHE, PY.TPFO..LOG,
# 			PY.TPFO..OCF, PY.TPFO..UHZ, PY.TPFO..UHN, PY.TPFO..UHE,
# 			PY.TPFO..VCO, PY.TPFO..VEA, PY.TPFO..VEC, PY.TPFO..VEP,
# 			PY.TPFO..VHZ, PY.TPFO..VHN, PY.TPFO..VHE, PY.TPFO..VKI,
# 			PY.TPFO..VM0, PY.TPFO..VM1, PY.TPFO..VM2, PY.TPFO..VM3,
# 			PY.TPFO..VM4, PY.TPFO..VM5, PY.TPFO..VM6, PY.TPFO..VPB,
# 			PY.TPFO.EP.BDF, PY.TPFO.EP.BDG, PY.TPFO.EP.BDO, PY.TPFO.EP.LCE,
# 			PY.TPFO.EP.LCO, PY.TPFO.EP.LDF, PY.TPFO.EP.LDG, PY.TPFO.EP.LDM,
# 			PY.TPFO.EP.LDO, PY.TPFO.EP.LEP, PY.TPFO.EP.LIM, PY.TPFO.EP.LKM

# %%
# st = cl.get_waveforms(network="PY", station="BSPF", location="", channel="HJZ", starttime=starttime, endtime=endtime)
st = cl.get_waveforms(network="PY", station="PFOIX", location="", channel="HH*", starttime=starttime, endtime=endtime)

# %%
# rotate stream back to UVW
from obspy.signal.rotate import rotate2zne

st.plot();

az_u = 90.0
dip_u = -(90.0 - 54.7)
az_v = 330.0
dip_v = -(90.0 - 54.7)
az_w = 210.0
dip_w = -(90.0 - 54.7)

# az_x = 65.0
# dip_x = 0.0
# az_y = 335.0
# dip_y = 0.0
# az_z = 0.0
# dip_z = -90.0

u,v,w = rotate2zne(
    st.select(channel="HHZ")[0].data,
    az_u, dip_u,
    st.select(channel="HHN")[0].data,
    az_v, dip_v,
    st.select(channel="HHE")[0].data,
    az_w, dip_w,
    inverse=True
)

st2 = st.copy()

for tr in st2:
    if tr.stats.channel == "HHE":
        tr.stats.channel = "HHU"
        tr.data = u
    elif tr.stats.channel == "HHN":
        tr.stats.channel = "HHV"
        tr.data = v
    elif tr.stats.channel == "HHZ":
        tr.stats.channel = "HHW"
        tr.data = w

# plot stream
st2.plot();

# %% [markdown]
# Initalize a sixdegrees object

# %%
sd = sixdegrees(conf=config)

# %% [markdown]
# Store the configuration as a pickle file

# %%
sd.store_as_pickle(config, "./event_configs/"+f"M{str(config['magnitude']).replace('.','')}_{config['tbeg'][:10].replace('-','')}")
# Out:
#  -> stored: ./event_configs/M62_20221122.pkl

# %% [markdown]
# Get key information about the event

# %%
ev = sd.get_event_info(origin_time=config['origin_time'],
                       base_catalog="USGS",
                       magnitude=config['magnitude'])
# Out:
# Found event:
# Origin time: 2022-11-22T16:39:05.789000Z
# Magnitude: 6.2 mww
# Location: 30.794°N, -116.391°E
# Depth: 10.0 km
# Distance: 2.8°
# Backazimuth: 178.9°

# %% [markdown]
# This will load the data from the specified data source:
# - local mseed file
# - local sds system
# - fdsn (online)

# %%
sd.load_data(config['tbeg'], config['tend'])
# Out:
# -> fetching PY.PFOIX..HHZ data from mseed file
# -> fetching PY.PFOIX..HHN data from mseed file
# -> fetching PY.PFOIX..HHE data from mseed file
# 0 Trace(s) in Stream:
#
# -> fetching PY.BSPF..HJZ data from mseed file
# -> fetching PY.BSPF..HJN data from mseed file
# -> fetching PY.BSPF..HJE data from mseed file
# 0 Trace(s) in Stream:
#
#  -> missing stream data

# %% [markdown]
# Ensure that all traces of stream have the same sample size

# %%
sd.trim_stream(set_common=True, set_interpolate=False)

# %% [markdown]
# Now we can have a look at the waveforms of all 6 components

# %%
sd.st.plot(equal_scale=False);
# Out:
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/imaging/util.py:266: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/andbro/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/imaging/waveform.py:815: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',

# %% [markdown]
# ### Only required for time lag correction

# %% [markdown]
# This computes the time lag between the translation and rotation components based on cross-correlation for transverse and vertical component combinations. If correction is True, the time lag is applied to the rotation component.

# %%
# #finde (and correct) time lag between translation and rotation data
# sd.get_component_lag(normalize=True,
#                      baz=ev['backazimuth'],
#                      correct=False)

# # update endtime
# sd.tend = sd.tbeg+25

# # trim stream
# sd.st = sd.st.trim(sd.tbeg, sd.tend)

# sd.st.plot(equal_scale=False);

# %% [markdown]
# ### Write data to file or SDS system

# %% [markdown]
# This allows to write the data to a file or the SDS system. For the mseed file the seed id is as specified in the config.

# %%
# write to mseed file
# sd.st.write("./data/eventM35_6c.mseed", format="MSEED")

# write to sds filesystem
# sd.write_to_sds(sd.st, "./data/", format="MSEED")

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Wavelet Comparsion

# %% [markdown]
# This allows to compute the CWT for all components and plot the results.

# %%
# First compute CWT for all components
cwt_results = {}
for comp in ['Z', 'N', 'E']:
    # Rotation components
    rot_data = sd.get_stream("rotation").select(channel=f"*{comp}")[0]
    cwt_results[f"{comp}_Rotation"] = sixdegrees.compute_cwt(
        rot_data.times(), rot_data.data, rot_data.stats.delta,
        normalize=True
    )
    
    # Translation components
    acc_data = sd.get_stream("translation").select(channel=f"*{comp}")[0]
    cwt_results[f"{comp}_Translation"] = sixdegrees.compute_cwt(
        acc_data.times(), acc_data.data, acc_data.stats.delta,
        normalize=True
    )

# Then plot all components
fig = sixdegrees.plot_cwt_all(
    rot=sd.get_stream("rotation"),
    acc=sd.get_stream("translation"),
    cwt_output=cwt_results,
    clog=True,
    ylim=50
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 5
#       2 cwt_results = {}
#       3 for comp in ['Z', 'N', 'E']:
#       4     # Rotation components
# ----> 5     rot_data = sd.get_stream("rotation").select(channel=f"*{comp}")[0]
#       6     cwt_results[f"{comp}_Rotation"] = sixdegrees.compute_cwt(
#       7         rot_data.times(), rot_data.data, rot_data.stats.delta,
#       8         normalize=True
#       9     )
#      11     # Translation components
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/core/stream.py:643, in Stream.__getitem__(self, index)
#     641     return self.__class__(traces=self.traces.__getitem__(index))
#     642 else:
# --> 643     return self.traces.__getitem__(index)
#
# IndexError: list index out of range

# %% [markdown]
# Frequency band to filter (this is applied to the stream object after being reset to raw stream)

# %%
# sd.filter_data(fmin=0.1, fmax=0.5, output=False)
# sd.filter_data(fmin=0.5, fmax=1.0, output=False)
sd.filter_data(fmin=5, fmax=10.0, output=False)

# %% [markdown]
# Apply polarity correction if needed. This is applied to the stream object that is processed. If raw is True, the polarity correction is applied to the raw stream too.

# %%
sd.polarity_stream(pol_dict={"HZ": 1, "JZ": 1}, raw=True)

# %% [markdown]
# Let's compare the waveforms of the rotation (red) and translational (black) components. According to the theory both should be in phase for plane waves, thus the cross-correlation should be close to 1.

# %%
fig = sd.plot_waveform_cc(rot0=sd.get_stream("rotation"),
                        acc0=sd.get_stream("translation"),
                        baz=ev['backazimuth'],
                        distance=ev['distance_km'],
                        fmin=sd.fmin, fmax=sd.fmax, 
                        twin_sec=0.5, twin_overlap=0.5,
                        )

# %% [markdown]
# Here we can compare the FFT spetra of the rotation and translational components.

# %%
# fig = sd.plot_spectra_comparison_fill(rot=sd.get_stream("rotation"), 
#                                       acc=sd.get_stream("translation"),
#                                       fmin=0.09, fmax=0.6,
#                                       ylog=False, xlog=False, fill=True
#                                       )

# %% [markdown]
# ### Backazimuth Estimate

# %% [markdown]
# Now we want to estimate the backazimuth of the event. We can do this by computing the cross-correlation between the rotation and translational components (representing Love and Rayleigh waves, respectively) for different backazimuths.

# %%
# First compute backazimuth
baz_results = sd.compute_backazimuth(
    wave_type='love',
    baz_step=1,
    baz_win_sec=0.5,
    baz_win_sec_overlap=0.5,
    out=True
)

# Then plot results
fig = sd.plot_backazimuth_results(
    baz_results,
    wave_type='love',
    baz_theo=ev['backazimuth'],
    cc_threshold=0.2,  # optional
)

# %%
# First compute backazimuth
baz_results = sd.compute_backazimuth(
    wave_type='rayleigh',
    baz_step=1,
    baz_win_sec=0.5,
    baz_win_sec_overlap=0.5,
    out=True
)

# # Then plot results
fig = sd.plot_backazimuth_results(
    baz_results,
    wave_type='rayleigh',
    baz_theo=ev['backazimuth'],
    cc_threshold=0.2,  # optional
)

# %% [markdown]
# We can also compare the different backazimuth estimation methods. This also includes a method based on the horizontal rotation components (called tangent method). This is then compared to the theoretical backazimuth (based on the event location).

# %%
fig, results = sd.compare_backazimuth_methods(
    Twin=0.5,
    Toverlap=0.5,
    invert_rot_z=False,
    invert_acc_z=False,
    cc_threshold=0.2,
    baz_theo=ev['backazimuth'],
    plot=True,
    output=True
)

# %% [markdown]
# ### Analyse phase velocities

# %% [markdown]
# 6 DoF observations allow us to estimate the phase velocities of Love and Rayleigh waves based on the amplitude ratios. For the estimation we use linear regression methods (ODR and RANSAC) to estimate the slope of rotational and translational amplitudes in time windows.

# %%
# Compute Love wave velocities
love_velocities = sd.compute_velocities(
    wave_type='love',
    win_time_s=0.5,
    overlap=0.5,
    cc_threshold=0.4,
    method='odr',
    baz=ev['backazimuth']  # optional
)

# Compute Rayleigh wave velocities
rayleigh_velocities = sd.compute_velocities(
    wave_type='rayleigh',
    win_time_s=0.5,
    overlap=0.5,
    cc_threshold=0.4,
    method='odr',
    baz=ev['backazimuth']  # optional
)

# %% [markdown]
# We can plot the results with the waveforms which are rotated using the theoretical backazimuth.

# %%
# Plot results
fig = sd.plot_velocities(
    velocity_results=love_velocities,
    vmax=5000,  # optional
    minors=True # optional
)

# Plot results
fig = sd.plot_velocities(
    velocity_results=rayleigh_velocities,
    vmax=5000,  # optional
    minors=True # optional
)

# %% [markdown]
# ### Optimization of parameters

# %% [markdown]
# This method allows to optimize the parameters for the velocity estimation. We scan frequency bands (the time window is then computed automatically) and backazimuths in a grid search and then select the best parameters based on the cross-correlation that are used for the velocity estimates.

# %%
# Get optimization results
params = sd.optimize_parameters(wave_type='love', 
                              fbands={'fmin': 1, 'fmax': 10.0, 'octave_fraction': 6}, 
                              baz_step=1,  # step size for the backazimuth search
                              twin_min=1,  # minimum time window in seconds
                              overlap=0.9,  # overlap of the time windows
                              bandwidth_factor=2  # bandwidth factor for the frequency band
                              )

# Plot results using the class method
fig = sd.plot_optimization_results(params, wave_type='love',
                                   vel_max_threshold=5000,
                                   cc_threshold=0.5,
                                   baz_theo=ev['backazimuth'])
plt.show()

# %%
# Get optimization results
params = sd.optimize_parameters(wave_type='rayleigh', 
                              fbands={'fmin': 0.1, 'fmax': 1.0, 'octave_fraction': 6}, 
                              baz_step=1,  # step size for the backazimuth search
                              twin_min=1,  # minimum time window in seconds
                              overlap=0.5,  # overlap of the time windows
                              bandwidth_factor=2  # bandwidth factor for the frequency band
                              )

# Plot results using the class method
fig = sd.plot_optimization_results(params, wave_type='rayleigh',
                                   vel_max_threshold=5000,
                                   cc_threshold=0.8,
                                   baz_theo=ev['backazimuth'])
plt.show()
