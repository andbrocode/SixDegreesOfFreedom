# %% [markdown]
# # Analyse Events with G-ring Data

# %% [markdown]
# An earthquake in 2024 is analysed using the G-ring laser rotation data for the vertical component (thus only for Love waves), which are availible via FDSN services online.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from sixdegrees import sixdegrees

# %% [markdown]
# ## Configurations

# %%
config = {
    # Required time window parameters
    'tbeg': "2024-12-05 18:44:21",  # Start time
    'tend': "2024-12-05 20:44:21",  # End time

    # event
    'origin_time': "2024-12-05 18:44:26",
    'magnitude': 7.0,

    # SEED identifiers
    'seed': "XX.RLAS..",     # seed ID of output stream
    'rot_seed': ["BW.RLAS..BJZ"], # Rotation sensor seed ID
    'tra_seed': ["GR.WET..BHZ", "GR.WET..BHN", "GR.WET..BHE"],  # Translation sensor seed ID
    
    # rotate to ZNE
    'rotate_to_zne': False,

    # Data source
    'data_source': "fdsn",  # "fdsn" | "sds" | "mseed_file"

    # FDSN client
    'fdsn_client_rot': "LMU",  # "IRIS",
    'fdsn_client_tra': "BGR",  # "IRIS",

    # Path to local mseed file
    # 'path_to_mseed_file': "./data/G_eventM7.0.mseed",  # "./data/eventM62_6c.mseed",

    # Path to SDS for rotation and translation data
    # 'path_to_sds_rot': "/home/andbro/freenas/temp_archive/",    # SDS path for rotation data
    # 'path_to_sds_tra': "/home/andbro/bay200/mseed_online/archive/",  # SDS path for translation data

    # Path to inventory of rotation and translation sensor
    # 'path_to_inv_rot': "/home/andbro/kilauea-data/stationxml_ringlaser/station_BW_RLAS.xml",  # Rotation station inventory
    # 'path_to_inv_tra': "/home/andbro/kilauea-data/stationxml_ringlaser/station_GR_WET.xml",  # Translation station inventory
    
    # Path configurations
    'workdir': "./",            # Working directory
    'path_to_data_out': "./output/",  # Output directory

    # Project information
    'project': "G_Analysis",  # Project name
    
    # Backazimuth calculation parameters
    'baz_step': 1,               # Step size for backazimuth search in degrees
    'time_win_sec': 30,          # Window length in seconds
    'time_win_sec_overlap': 15,  # Window overlap in seconds
    
    # Optional parameters
    'verbose': True,            # Print detailed information
}

# %% [markdown]
# Setup a sixdegrees object

# %%
sd = sixdegrees(conf=config)

# %% [markdown]
# This will load the data from the data source:
# - local mseed file
# - local sds system
# - fdsn (online)
#
# and trim it to the time window

# %%
print(sd.rot_inv)
# Out:
# None

# %%
sd.rot_inv_file
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sd.rot_inv_file
#
# AttributeError: 'sixdegrees' object has no attribute 'rot_inv_file'

# %%
sd.load_data(config['tbeg'], config['tend'])
# Out:
# -> fetching GR.WET..BHZ data from FDSN
# -> fetching GR.WET..BHN data from FDSN
# -> fetching GR.WET..BHE data from FDSN
# -> successfully removed response
# 3 Trace(s) in Stream:
# GR.WET..BHZ | 2024-12-05T18:44:20.020000Z - 2024-12-05T20:44:22.020000Z | 20.0 Hz, 144041 samples
# GR.WET..BHN | 2024-12-05T18:44:20.020000Z - 2024-12-05T20:44:22.020000Z | 20.0 Hz, 144041 samples
# GR.WET..BHE | 2024-12-05T18:44:20.020000Z - 2024-12-05T20:44:22.020000Z | 20.0 Hz, 144041 samples
# -> fetching BW.RLAS..BJZ data from FDSN
# -> error processing rotation data: 'sixdegrees' object has no attribute 'rot_inv_file'
# 1 Trace(s) in Stream:
# BW.RLAS..BJZ | 2024-12-05T18:44:19.981749Z - 2024-12-05T20:44:21.981749Z | 20.0 Hz, 144041 samples

# %% [markdown]
# Get key information about the earthquake

# %%
ev = sd.get_event_info(
    origin_time=config['origin_time'],
    base_catalog="USGS",
    magnitude=config['magnitude']
)
# Out:
# Found event:
# Origin time: 2024-12-05T18:44:21.110000Z
# Magnitude: 7.0 mw
# Location: 40.374°N, -125.022°E
# Depth: 10.0 km
# Epicentral Distance: 9264.5 km
# Epicentral Distance: 83.3°
# Backazimuth: 329.1°

# %% [markdown]
# Ensure that all traces of stream have the same sample size

# %%
sd.st.plot(equal_scale=False);

# %%
sd.trim_stream(set_common=True, set_interpolate=False)

# %% [markdown]
# ### Write data to file or SDS system

# %%
# write to mseed file
# sd.st.write(f"./data/G_eventM{config['magnitude']}.mseed", format="MSEED")

# write to sds filesystem
# sd.write_to_sds(sd.st, "./data/", format="MSEED")

# %% [markdown]
# ## Analysis

# %%
sd.get_theoretical_arrival(phase='p')
# Out:
# No theoretical arrivals found for phase p

# %% [markdown]
# ### Wavelet Comparsion

# %%
# First compute CWT for all components
cwt_results = {}
for comp in ['Z', 'N', 'E']:

    try:
        # Rotation components
        rot_data = sd.get_stream("rotation").select(channel=f"*{comp}")[0]
        cwt_results[f"{comp}_Rotation"] = sd.compute_cwt(
            rot_data.times(), rot_data.data, rot_data.stats.delta,
            normalize=True
        )
    except:
        print(f"No {comp} data for rotation")
    try:
        # Translation components
        acc_data = sd.get_stream("translation").select(channel=f"*{comp}")[0]
        cwt_results[f"{comp}_Translation"] = sd.compute_cwt(
            acc_data.times(), acc_data.data, acc_data.stats.delta,
            normalize=True
        )
    except:
        print(f"No {comp} data for ranslation")
# Out:
# No Z data for ranslation
# No N data for rotation
# No E data for rotation

# %%
# Then plot all components
fig = sixdegrees.plot_cwt_all(
    rot=sd.get_stream("rotation"),
    acc=sd.get_stream("translation"),
    cwt_output=cwt_results,
    clog=True,
    ylim=1
)

del fig

# %% [markdown]
# Frequency band to filter (this is applied to the stream object after being reset to raw stream)

# %%
sd.filter_data(fmin=0.01, fmax=0.1, output=False)

# %% [markdown]
# Apply polarity correction if needed. This is applied to the stream object that is processed. If raw is True, the polarity correction is applied to the raw stream too.

# %%
sd.polarity_stream(pol_dict={"HZ": 1, "JZ": 1}, raw=True)

# %% [markdown]
# let's compare the waveforms of the rotation (red) and translational (black) components

# %%
fig = sd.plot_waveform_cc(rot0=sd.get_stream("rotation"),
                        acc0=sd.get_stream("translation"),
                        baz=ev['backazimuth'],
                        distance=ev['distance_km'],
                        fmin=sd.fmin, fmax=sd.fmax, 
                        twin_sec=50, twin_overlap=0.5,
                        wave_type='love'
                        )

# %%
# fig = sd.plot_spectra_comparison_fill(rot=sd.get_stream("rotation"), 
#                                       acc=sd.get_stream("translation"),
#                                       fmin=0.09, fmax=0.6,
#                                       ylog=False, xlog=False, fill=True
#                                       )

# %% [markdown]
# ### Backazimuth Estimate

# %%
# First compute backazimuth
baz_results = sd.compute_backazimuth(
    wave_type='love',
    baz_step=1,
    baz_win_sec=100,
    baz_win_sec_overlap=0.5,
    out=True
)
# Out:
# using love waves for backazimuth estimation ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # First compute backazimuth
# ----> 2 baz_results = sd.compute_backazimuth(
#       3     wave_type='love',
#       4     baz_step=1,
#       5     baz_win_sec=100,
#       6     baz_win_sec_overlap=0.5,
#       7     out=True
#       8 )
#
# File ~/cursorfiles/sixdegrees/scripts/sixdegrees.py:1355, in sixdegrees.compute_backazimuth(self, wave_type, baz_step, baz_win_sec, baz_win_sec_overlap, out)
#    1349 R, T = rotate_ne_rt(ACC.select(channel='*N')[0].data,
#    1350                     ACC.select(channel='*E')[0].data,
#    1351                     backazimuths[i_deg]
#    1352                    )
#    1354 # compute correlation for backazimuth
# -> 1355 ccorr = correlate(ROT.select(channel="*Z")[0][idx1:idx2],
#    1356                   T[idx1:idx2],
#    1357                   0, demean=True, normalize='naive', method='fft'
#    1358                  )
#    1360 # get maximum correlation
#    1361 xshift, cc_max = xcorr_max(ccorr)
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/cross_correlation.py:159, in correlate(a, b, shift, demean, normalize, method)
#     157 # choose the usually faster xcorr function for each method
#     158 _xcorr = _xcorr_padzeros if method == 'direct' else _xcorr_slice
# --> 159 cc = _xcorr(a, b, shift, method)
#     160 if normalize == 'naive':
#     161     norm = (np.sum(a ** 2) * np.sum(b ** 2)) ** 0.5
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/obspy/signal/cross_correlation.py:63, in _xcorr_slice(a, b, shift, method)
#      60 if shift > mid:
#      61     # Such a large shift is not possible without zero padding
#      62     return _xcorr_padzeros(a, b, shift, method)
# ---> 63 cc = scipy.signal.correlate(a, b, mode='full', method=method)
#      64 return cc[mid - shift:mid + shift + len(cc) % 2]
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_signaltools.py:242, in correlate(in1, in2, mode, method)
#     240 # this either calls fftconvolve or this function with method=='direct'
#     241 if method in ('fft', 'auto'):
# --> 242     return convolve(in1, _reverse_and_conj(in2), mode, method)
#     244 elif method == 'direct':
#     245     # fastpath to faster numpy.correlate for 1d inputs when possible
#     246     if _np_conv_ok(in1, in2, mode):
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_signaltools.py:1414, in convolve(in1, in2, mode, method)
#    1411     method = choose_conv_method(volume, kernel, mode=mode)
#    1413 if method == 'fft':
# -> 1414     out = fftconvolve(volume, kernel, mode=mode)
#    1415     result_type = np.result_type(volume, kernel)
#    1416     if result_type.kind in {'u', 'i'}:
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_signaltools.py:670, in fftconvolve(in1, in2, mode, axes)
#     665 s2 = in2.shape
#     667 shape = [max((s1[i], s2[i])) if i not in axes else s1[i] + s2[i] - 1
#     668          for i in range(in1.ndim)]
# --> 670 ret = _freq_domain_conv(in1, in2, axes, shape, calc_fast_len=True)
#     672 return _apply_conv_mode(ret, s1, s2, mode, axes)
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/signal/_signaltools.py:508, in _freq_domain_conv(in1, in2, axes, shape, calc_fast_len)
#     505     fft, ifft = sp_fft.fftn, sp_fft.ifftn
#     507 sp1 = fft(in1, fshape, axes=axes)
# --> 508 sp2 = fft(in2, fshape, axes=axes)
#     510 ret = ifft(sp1 * sp2, fshape, axes=axes)
#     512 if calc_fast_len:
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/fft/_backend.py:25, in _ScipyBackend.__ua_function__(method, args, kwargs)
#      23 if fn is None:
#      24     return NotImplemented
# ---> 25 return fn(*args, **kwargs)
#
# File ~/anaconda3/envs/obs2/lib/python3.10/site-packages/scipy/fft/_pocketfft/basic.py:215, in r2cn(forward, x, s, axes, norm, overwrite_x, workers, plan)
#     212     raise TypeError("x must be a real sequence")
#     214 shape, axes = _init_nd_shape_and_axes(tmp, s, axes)
# --> 215 tmp, _ = _fix_shape(tmp, shape, axes)
#     216 norm = _normalization(norm, forward)
#     217 workers = _workers(workers)
#
# KeyboardInterrupt:

# %%
# plot results
fig = sd.plot_backazimuth_results(
    baz_results,
    wave_type='love',
    baz_theo=ev['backazimuth'],
    cc_threshold=0.5,  # optional
)
# Out:
# max = 310, mean = 288.0, std = 52.01718064803

# %% [markdown]
# ### Analyse phase velocities

# %%
# Compute Love wave velocities
love_velocities = sd.compute_velocities(
    wave_type='love',
    win_time_s=50.0,
    overlap=0.5,
    cc_threshold=0.,
    method='odr',
    baz=ev['backazimuth']  # optional
)

# %%
# Plot results
fig = sd.plot_velocities(
    velocity_results=love_velocities,
    vmax=6000,  # optional
    minors=True, # optional
    cc_threshold=0.7

)
